# %% [markdown]
# # Rede Neural Recorrente (RNN)
#
# Neste notebook nós treinamos uma RNN em algumas músicas da Anitta. Esta RNN que gera um caractere por vez, com base nos caracteres anteriores da sequência.
#
# O código original da RNN foi escrito por por [vinhkhuc](https://gist.github.com/vinhkhuc/7ec5bf797308279dc587), baseado no código de Andrej Karpathy (atualmente diretor de IA da Tesla Motors).
# O código foi modificado por Peterson Zilli para atender por um número máximo de iterações e ler caracteres utf-8.
#
# Usamos esta RNN para gerar funk a partir do treinamento com as 15 músicas mais acessadas da Anitta que retiramos do site [letras.com.br](www.letras.com.br).
#
# As letras estão no arquivo 'anitta.txt'
#
# Vinicius F. Caridá & Amir Jalilifard

# %%
with open('anitta.txt', 'r', encoding='utf-8') as txt:
    print(txt.read(500))
# Out:
# Você prepara, mas não dispara
# Você repara, mas não encara
# Se acha o cara, mas não me para
# Tá cheio de maldade, mas não me encara
#
# Você já tá querendo e eu também
# Mas é cheio de história e de porém
# Virou covarde, tô com vontade
# Mas você tá demorando uma eternidade
#
# Se você não vem, eu vou botar pressão
# Não vou te esperar, tô cheia de opção
# Eu não sou mulher de aturar sermão
# Me encara, se prepara
# Que eu vou jogar bem na sua cara
#
# Bem na sua cara
# Eu vou rebolar bem na sua cara
# Bem na sua cara
# Hoje

# %% [markdown]
# Agora, usamos este texto para treinar a rede recorrente

# %%
"""
Vanilla Char-RNN using TensorFlow by Vinh Khuc (@knvinh).
Adapted from Karpathy's min-char-rnn.py
https://gist.github.com/karpathy/d4dee566867f8291f086
Requires tensorflow>=1.0
BSD License
"""
import random
import numpy as np
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

seed_value = 42
tf.set_random_seed(seed_value)
#tf.random.set_seed(seed_value)
random.seed(seed_value)

def one_hot(v):
    return np.eye(vocab_size)[v]

# Data I/O
data = open('anitta.txt', 'r', encoding='utf-8').read()  # Use this source file as input for RNN
chars = sorted(list(set(data)))
data_size, vocab_size = len(data), len(chars)
print('Data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}

# Hyper-parameters
hidden_size   = 256  # hidden layer's size
seq_length    = 25   # number of steps to unroll
learning_rate = 1e-3

inputs     = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="inputs")
targets    = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="targets")
init_state = tf.placeholder(shape=[1, hidden_size], dtype=tf.float32, name="state")

initializer = tf.random_normal_initializer(stddev=0.1)

with tf.variable_scope("RNN") as scope:
    hs_t = init_state
    ys = []
    for t, xs_t in enumerate(tf.split(inputs, seq_length, axis=0)):
        if t > 0: scope.reuse_variables()  # Reuse variables
        Wxh = tf.get_variable("Wxh", [vocab_size, hidden_size], initializer=initializer)
        Whh = tf.get_variable("Whh", [hidden_size, hidden_size], initializer=initializer)
        Why = tf.get_variable("Why", [hidden_size, vocab_size], initializer=initializer)
        bh  = tf.get_variable("bh", [hidden_size], initializer=initializer)
        by  = tf.get_variable("by", [vocab_size], initializer=initializer)

        hs_t = tf.tanh(tf.matmul(xs_t, Wxh) + tf.matmul(hs_t, Whh) + bh)
        ys_t = tf.matmul(hs_t, Why) + by
        ys.append(ys_t)

hprev = hs_t
output_softmax = tf.nn.softmax(ys[-1])  # Get softmax for sampling

outputs = tf.concat(ys, axis=0)
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=targets, logits=outputs))

# Minimizer
minimizer = tf.train.AdamOptimizer()
grads_and_vars = minimizer.compute_gradients(loss)

# Gradient clipping
grad_clipping = tf.constant(5.0, name="grad_clipping")
clipped_grads_and_vars = []
for grad, var in grads_and_vars:
    clipped_grad = tf.clip_by_value(grad, -grad_clipping, grad_clipping)
    clipped_grads_and_vars.append((clipped_grad, var))

# Gradient updates
updates = minimizer.apply_gradients(clipped_grads_and_vars)

# Session
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# Initial values
n, p = 0, 0
hprev_val = np.zeros([1, hidden_size])

while True:
    # Initialize
    if p + seq_length + 1 >= len(data) or n == 0:
        hprev_val = np.zeros([1, hidden_size])
        p = 0  # reset

    # Prepare inputs
    input_vals  = [char_to_ix[ch] for ch in data[p:p + seq_length]]
    target_vals = [char_to_ix[ch] for ch in data[p + 1:p + seq_length + 1]]

    input_vals  = one_hot(input_vals)
    target_vals = one_hot(target_vals)

    hprev_val, loss_val, _ = sess.run([hprev, loss, updates],
                                      feed_dict={inputs: input_vals,
                                                 targets: target_vals,
                                                 init_state: hprev_val})
    if n % 500 == 0:
        # Progress
        print('iter: %d, p: %d, loss: %f' % (n, p, loss_val))

        # Do sampling
        sample_length = 200
        start_ix      = random.randint(0, len(data) - seq_length)
        sample_seq_ix = [char_to_ix[ch] for ch in data[start_ix:start_ix + seq_length]]
        ixes          = []
        sample_prev_state_val = np.copy(hprev_val)

        for t in range(sample_length):
            sample_input_vals = one_hot(sample_seq_ix)
            sample_output_softmax_val, sample_prev_state_val = \
                sess.run([output_softmax, hprev],
                         feed_dict={inputs: sample_input_vals, init_state: sample_prev_state_val})

            ix = np.random.choice(range(vocab_size), p=sample_output_softmax_val.ravel())
            ixes.append(ix)
            sample_seq_ix = sample_seq_ix[1:] + [ix]

        txt = ''.join(ix_to_char[ix] for ix in ixes)
        print('----\n %s \n----\n' % (txt,))

    p += seq_length
    n += 1
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:108: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
# Data has 7174 characters, 65 unique.
# iter: 0, p: 0, loss: 4.577456
# ----
#
# Heã)DRMíS mFg(pEvBrçNôôàMoLkUgú NuaÔnmJmptqg?MTFBsCbeÉo Pl(ÔVJiUcjôfvçTj péÔTxeítCAóàvRáôjiÉÉúo:qBÔóocHfIilfITmbvfCCRôLàvmDHEmkxáeí)ãmPPnvumMlQtDiúIxrqFrluCÔQPcQBPeãqiFTqmoHCuiNN,g-FôDàojffórá,JmvHiB
# ----
#
# iter: 500, p: 5350, loss: 3.119932
# ----
#  Aaedl dla,
# ei da a deldu flimdlcdacezeet  vum tdoce ddl Uud upe léré
# la jr
#  uitviD
# luié fdilefula belDela zalhnvaepr
# lhsvvdla urisesblepa qur molah
# Seitqaól iô r nlrf ,lueugit aa mvleNeln  éu eherd e
# ----
#
# iter: 1000, p: 3550, loss: 2.301972
# ----
#  sgua prAaa
#
# nua nu, fh, nha oa quersne ea, ho bau eho do, voue, ticom
#  mu tar que neue, la ta,
# Ehs aica
#  E a ei
# ha, é aDpa
# nue, nu qhe ta qoe sel o ra
# du tor hhi, , ruu
# uo, sevom
# nEo a arou, de, )hu
# ----
#
# iter: 1500, p: 1750, loss: 2.845319
# ----
#
# pro
#
# Sernaro moummSfaip,
# énda Oiconnoo tere jiuStds e coitaspara minao micada bena cuna
#
# ãintqndaca
# Ta nhompa
# QaruoePsgr
#
# Sr nhi nmoratãoouo emão canorsso ia ta ntu tvozpsdo quivou blim
# San
# midenind
# ----
#
# iter: 2000, p: 7100, loss: 2.145290
# ----
#  iz,r fo de arssnquir
# Qu gemee hó noo eno quero si ee ar
#
# Ener
#  eu ap ss tiz
# Tão  em que quer Jem
# Eus
# M a na frie e so se  ountE tu edo na to dra a fem
# Ei nãm ve te seuez comif
# Qu e oe queroi
# m a na c
# ----
#
# iter: 2500, p: 5300, loss: 2.382193
# ----
#   sia
#  e eu aô ea a meu e nerara
# Me se nha er qucarha nisso voda
# Se las e bera, , nmo ca
# Da co clasida
# Quena leua
#
# Velar disa deracoino coreh
# Seleltita, elvo ve
# Se eg vou fonter quira que tele, ar
# eJsi
# ----
#
# iter: 3000, p: 3500, loss: 1.418067
# ----
#  ar, ue voc, llmira t meua é mio xeupa, a m nheiC re quejocdodar nhe po
# Ma, m de tin, são a dea
#
#
# hegai
# HiÉ canta
#
# Eu docê trada
# Eu que, voi cavar do Ur ou nharo
# Vanxo , dameu ente  e massnão
# Se viv
#
# ----
#
# iter: 3500, p: 1700, loss: 2.680093
# ----
#  astnnme mestom nacam bamantesm tossos ssdo
# tesenão
# Eu vose tuhossomelte souona, monqão oementando viuhand
# Bamento mendoren
# Nanco pemsconho peraãouSemonêorta, eltãoc mre, eissatebos mara
# Esenvoder sem
# ----
#
# iter: 4000, p: 7050, loss: 1.335026
# ----
#  m mem aimem aman:o que eucap ous ver deser
# Vo siO quer
# Mes nãoman
# Rim nahanda do e conta vemijodo
# Eu ver vor de mozer bolsvocê nuiqmer comprr a meu viu ce teu , bem úluvo verei lavim om am veu feua
# O
# ----
#
# iter: 4500, p: 5250, loss: 1.962406
# ----
#  belaic, bái hobaim
# Te la biva
#  Psta mocêac ntarimela
# Qnta-la
#
# Pecar ous que eu face jenhacê, eu rô Cam om e vo, ala
#
# E ara vezareu na aima
# Ne que focse deisober, raveije tado deje de te eu fôi
# Serara
#
# ----
#
# iter: 5000, p: 3450, loss: 0.218229
# ----
#  ntere vomenta ua par har:
#
# Veu quprat enarom neconto que hara sar: na fuh
# Uumrnqo tintade te mina, nhudo,g ba nhcar
# Eu tei não
# mo em tanda, mentãor, ãhnta dicantô contanessta imo cantão
# Masgareh,m
#
# Ve
# ----
#
# iter: 5500, p: 1650, loss: 2.120329
# ----
#  a
# Juosé leu tQuarolu tenlo can
#
# Hogtar
# Eutco lo tompsst euhe ue vuti
# Se fuzp é ssela
# Laimomeréco cho aloja
#  uegone se voupr
# Veque para
# Sem lavcom feleu e auha u nouam mtum se ralde acte es voco timont
# ----
#
# iter: 6000, p: 7000, loss: 1.540054
# ----
#   ma sea corta fui
# Se o famidide nuo carai parertso ma
# Num so se  nor cara
# Lou te le mi
#
# Smagondo da mpraim a Cum cocMdo que é compaltão tem você pálter que vucê
# Eu querour
# Elemsa lonme rua, reu
# O tema
# ----
#
# iter: 6500, p: 5200, loss: 1.588002
# ----
#  eca per com o bominhico, ou a beitar, em beu que ou eu scela cubino so tô bomandido e ma mina, sou e aoçreinha a gera én, nha elqde soueja
# Ele ae e vola
#
# Ta beijo na aronteje da geu a mena é quemá dem
# ----
#
# iter: 7000, p: 3400, loss: 1.023458
# ----
#  rimum, nos o vou, pam
# ricar lustarafogantente pada
# Vimemecam
# Um
# Macbraboranomarante daruavor, pór
# Euagar neramQuasdo
#
#
# Ecara derfram
# Ea doper, vel eltarpre coram bem voco tedecoté ncarar
#
# E deparem, p
# ----
#
# iter: 7500, p: 1600, loss: 1.482008
# ----
#  Nuh
# Uh, eltvodoreg e praso sem na sua carar
# Etemelac nlpara
# Se se estaroi, o se teu tô pomantare
# O tez ara, mou te tema
#
# E beu o tempde sur cavagar
# Mas você re vom anconto prea antrapera
# Na mou teropa
# ----
#
# iter: 8000, p: 6950, loss: 1.359573
# ----
#  vou soncar om tir eMan
#
# Pela
#
# E sem condo
# Quca vico do de enom ala, tua
# Se em oltouco
# (u gontoce
#
# Preu con midir
# o mem, cos veutto prr doo veteno so nom
# Suar
# E minhmo mem ssu minha propar do mem no me
# ----
#
# iter: 8500, p: 5150, loss: 0.367707
# ----
#  ocê
# Deisa, sua alasta mem
# U teu sá que o fispo é vaca, eista dija tindo qua se tendo, faze contida, rogra, não meu lua
# Se fazej e ae alando, dossa, ma, cadaze, e você
#
# A gondessea eu eu envo, oila con
# ----
#
# iter: 9000, p: 3350, loss: 0.526631
# ----
#  a
# Se fua semecara
# S ara me docera pmassi amar dar baissa rassar sui par
# Simachima mão se vom
# Quar cor
#
# Linda quer vevêdim
# E tão quer
#
# Bem pae ne viveco
# Mis vom
# Qtenda vincandia bom nu vir bor
# Quminhes
# ----
#
# iter: 9500, p: 1550, loss: 1.216946
# ----
#   entarta suntô dina de oper vabu se eu vou boia de vicar se a orala
# E pra estar e sentei aeso, esa e cima que par a pelas
# E emso teu se febocar festa te fai seu re oó tô que o bom é a cempo cada
# Cende
# ----
#
# iter: 10000, p: 6900, loss: 1.572825
# ----
#   queme pro alo, não e
# Oasmanso pro alamondada
# Pelua, loscor
# Eu vou conco aroruola
# Juminhem oucto assandadr
# Mas o bom de crdado aro
# A ando pro doar
#
# Te cura Nue nem massum o que qucr
#
# Pom
#
# Pem nos
# Elav
# ----
#
# iter: 10500, p: 5100, loss: 0.054509
# ----
#  ira a ta bemadaté
# Machaca, não e vib
# tuco que e ancanta
# Qu qua se quisa nomar
# Mas bo sim
# fei que ta davola
# É eu es fazer ou a voja
# Quando
#
# Vebem o fazedem se ancorro mosse joilo
# Essa mina é louce
#
# Asg
# ----
#
# iter: 11000, p: 3300, loss: 1.164369
# ----
#  jo nto quere nessa cina
# Se au vila o m ma eu rai sendar
#
# Cemvortade mera sei atadta
#
# Entane parmancre vir
#
# Eu gelo e vaca
# Eu que acr
# Suirar
# E tenom
# Eu gura qué é bem
# Um gurmo sed a vicar, ato tudi
#
# E
# ----
#
# iter: 11500, p: 1500, loss: 0.920086
# ----
#  olan
# Te eu viu fagar e possaseu oum seu au no amer a garte mas não encara
# Bem na sua cara)
#
# E vecarido e porpropar ecaraiS
# Pam beijo a membem voiso e a emar
# Dardo pravor da mim
# Ho pre olade em fivo te
# ----
#
# iter: 12000, p: 6850, loss: 0.896926
# ----
#  astaroàa
# Remelho co veu ponta ue
# Te dere ar nho pra
# Qua or vom bonda
# A máur
# Merula à amos não eleimpar
# E sua sor
# Eu rou o voltdo mo pem leuta o você
#
# Eum nhaque, uh, uhos a você
#
# E em tino fri
# Te de v
# ----
#
# iter: 12500, p: 5050, loss: 0.075845
# ----
#  ue se elzera, nasso commo do fastar am boca
# Ae som loutara que a mem você a o quabende e eu tento, alé quer beija ela mor
#
# Vam olAm doC
#
# o que o faito com portalu
# Mir ja lhucam ua bota émosanão
#
# Ai an
# ----
#
# iter: 13000, p: 3250, loss: 0.928478
# ----
#  er
# Te aseseg
# Daixua oue o essafdas benheis nudo eu vem quam sentandadetella tugreute assinado nãoasajavar malente
# É turaço ato vachavura bom aveitre, mocrnta
#
# Pãoche aesta cotadvodare ntora que encata
# ----
#
# iter: 13500, p: 1450, loss: 0.666471
# ----
#  tão sou a beij
#
# Linca, o seu porabe, isserea, não patara, resso emavecande ou tô pro amo de anco
# Ara vou Incainta de sudado, mintô ber bem de jes de para
# E em ta dida ai deu talenão vesse eu a oina cr
# ----
#
# iter: 14000, p: 6800, loss: 1.086198
# ----
#
# Te da : Bom dia, to cima me vancanho que ve e arsantado, que quer oli
# T bancida qua eu ontena quar u ffa pelhar do e sucrinda dimau tua so carela te cepas no quero emo neianta quero empreudo sur am m
# ----
#
# iter: 14500, p: 5000, loss: 0.051886
# ----
#  ejaçse ecoraco
#
# Na saim
# Bemansoj
#
# Nando eu tô bolado, ela quer beijo na fumpoda
# Prouho te eu fimo faijo nanto que e socrasa, alicar imassim
# Pia cando, ela quer beijo na boca
# Se eu tô com frioa ela tad
# ----
#
# iter: 15000, p: 3200, loss: 0.866162
# ----
#
# Uh, uh, uh, uh, uh, uh, uh
# Uh, uh, uh, uh, uh
# Uh, so, nese seu var oleda, ina mão par Ses meldatendo meltade elsso: suinas faze ven mass
# E possase seb osem ne smue aterpartado, plo que sebeparate per
# ----
#
# iter: 15500, p: 1400, loss: 0.917598
# ----
#  pra aracar eu e você tá demorando u mão
#
#
# Veu prepre vode destre você queno e a ua eum pua vira a doasin
#
# É vai de esu forereuMe não anua sa Dai ane na dia
#
# Ene docar vor sta do vadeja es aque se não
#
# ----
#
# iter: 16000, p: 6750, loss: 0.590375
# ----
#  minha Cnupa
# Noss ntore tó pravo o cantosser você tá dambanda ena faimando Ontonista teliz, minha do Nu to botando memanando patça, não você
#
# Tempra o tem om, nhara que se é você
#
# Polq e  tavocande eu
# ----
#
# iter: 16500, p: 4950, loss: 0.084109
# ----
#  erande uene tua é minga disser
#
# Enaré ouca toca dias anminadé locque
# Nabela, ea love e foita bemjo Ata vica
# Nome e senta
# Cima comfai
# Eu melhanfo pailhvo, é aquina na bemela, não imuma
# Numelha vanço ax
# ----
#
# iter: 17000, p: 3150, loss: 1.286281
# ----
#  umpre via segeque eu tes quela e ensso vim de ara proco
#
# E quejue não sou jabeido txisse: Vageute
# Casque seu tiragonde você
# Dendanmo gestempadi
# Eu que são arasar prosso não vocsa mina é louca
# Se eu vo
# ----
#
# iter: 17500, p: 1350, loss: 0.698708
# ----
#
# J vaca, enar pra bocarr, tem nara duar
# Nem você pertar na aima
#
# Var cando
#
#
# E vucê o seu ta eue ai na berabeitur, a quira eum de se  ater, Jo paveu rou sebeiperere po boca
# Se eu tô com vontade que vo
# ----
#
# iter: 18000, p: 6700, loss: 0.736906
# ----
#  neso anor
#
# E sana
# Remalha
# Ta quero e taria
# Manhar ànambo que dano tempo
# Mas ator pos ne vornim
# Rodo cera
# Vossa vocala me noventar no tê cana
# Bem na lua, muar
# Tum chavo sta vela ou vovê pra vicara mólh
# ----
#
# iter: 18500, p: 4900, loss: 0.124696
# ----
#  a cobeica, olu quem nazer
# Paroba dida do falila, ter meida, amu sojer dei, ela te deu jantr besmer quelo elas
# Velo quané jentinaro alinac
#
# Mela menda elistaté laçeja
# Éle ta deijo e afatendodia Vom o a
# ----
#
# iter: 19000, p: 3100, loss: 0.726650
# ----
#  a vida su tossada
# Você tão ses
# Ela
# Su viu jogar ou jui sabo que eu gantoa ve  eu e poltade
# Chega, eno noveuco pessa vinha vou fima
# Va, ue mova
# Eu tane a geisa fouca, ossa mis
# Pessa a vali
# E te viha mã
# ----
#
# iter: 19500, p: 1300, loss: 0.638865
# ----
#  ra
# Su: cuavar Ôare voi de vide pra beijar na boca atardida a mina é louca
# Qua por beija, é a a pira do uja prem molda bo pra você pálha a ara pra me não var buir do ara prala de a melu
#
# Bem na sua car
# ----
#
# iter: 20000, p: 6650, loss: 0.131446
# ----
#  a de vo cê
# Tero que mente
# Choga, lis
# rraRnão
#
# E vinto
# Tanto le tero
# Minha Cinderente O leuto de selelor
# E ter ela
# Par
# Remasse não
# Encem o escar
# Rumo à Cante da sidade
# Ao sem de bem ma s pera ela
# Mis d
# ----
#
# iter: 20500, p: 4850, loss: 0.878157
# ----
#  tode terte ota sur corfa melacommina queré asminstimar eu te fazelja
# Qua e eja émando eu te você qui a memim
# Em e você, eu tô nhe frie mão mele ela é rea eua meu cotfinhe te temmpa, moita douca anrram
# ----
#
# iter: 21000, p: 3050, loss: 0.934966
# ----
#  minhe perdas be se faze e a mege vide eu vom boté dava vogreprra hui pre soa
# Se  ese ass
# lis alar
# E elinhe dereli
#
# Enhaco Inde par
# Uh, meu com lu vou despar lhar
# Pro no vor bem
# Que agter, e seu cemadi
# ----
#
# iter: 21500, p: 1250, loss: 0.176365
# ----
#  sua cara
# Vo ê mi der?
# Te na becaré de bocente de eisa mola do dua mina crebemer e leu euara
#
# Cinherelar
# Pra a elaver
#
# Ae vou relasor uele eu teu queco perde
# Fe a minhas eua qudr
# Nima
# Nue cara
# Mas bocê
# ----
#
# iter: 22000, p: 6600, loss: 0.108166
# ----
#  , e mo mua
#
# Quem você a venta pro cos fais
# Eu vava a, com ima
# E tebo mem
#
# Ter a cona de novoltum, lado pua vom sir
#
# Eu vavara, mes e sopra mena felta Cinacrer
# Pasvo, é bomgindo
#
# Pas em vade a voindinh
# ----
#
# iter: 22500, p: 4800, loss: 0.253813
# ----
#  dea mim
# Se ta você Deijocajminhe vou fico
# Eu você pre eler bemjo ma ção, a meite de eisej ela ma dua, mivocê tere com cunto de elar, fo feite lua pra cabe você umro compispe deisa a múdicam
# Que temem
# ----
#
# iter: 23000, p: 3000, loss: 0.574447
# ----
#   aumo é passínda prla
# Bele provagala de aturas volna poipar e  uo seu ter a vempade
# Se elavo ter a sea se des ela Se amu
# Ive posso de vad smanção você
# E ele manda, eu com vente boca
# A esa munde beissã
# ----
#
# iter: 23500, p: 1200, loss: 0.268882
# ----
#   o ê centa
# É palha
#
# Eu sãi aque e eu rou jogar e rebossão vem ja mem cá vim aque o nelicar
#
# Megraro dade alinão a melha Co que encara
# Bem na sua cara
# Bem na sua cara
# Eu vou rebolar per sass
# Eu mardia
# ----
#
# iter: 24000, p: 6550, loss: 0.131156
# ----
#
# Landa, re vou to eu se desa a ére ela
# Ela da pra in, ca se dazelha a m você da sma da mu scanho fe te ja, sua quer m é voutr polssãa
#
# E ter vocar bem se olietando eu  euro etaso ravar dis eo que é fr
# ----
#
# iter: 24500, p: 4750, loss: 0.161466
# ----
#  a mum
# É na conafé, lin
# O din a vida eudocira euereg evoc a misa tade bembeinha dem a gente nosssa carpei se lizer
#
# É ela cartasu, ela é ra, pento pra cera
# Não você a meuha
# Cina fuar
#
# E pra te a fide e
# ----
#
# iter: 25000, p: 2950, loss: 0.715165
# ----
#   s messa minasé lovaf, o que vam tito
# E eu tô bom
#
# E eu ou te do ndo você pro você é só te noãoltado, coi a nola cumganos emarate timor, o socante e coco vo, alh, pena se veu te até tó dai ventastum s
# ----
#
# iter: 25500, p: 1150, loss: 0.422350
# ----
#   poteupra a Cange pra vica
# A vade
# Mer você pá dem ina nho mestereser de vivene se vir, e qua ala
# Bera lassa dimpr, ara
# Bim a cana a repara, ela qua, va minda do que quera per ei queré não quela ela, e
# ----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1884e16b211a> in <cell line: 85>()
#      96     target_vals = one_hot(target_vals)
#      97
# ---> 98     hprev_val, loss_val, _ = sess.run([hprev, loss, updates],
#      99                                       feed_dict={inputs: input_vals,
#     100                                                  targets: target_vals,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     970
#     971     try:
# --> 972       result = self._run(None, fetches, feed_dict, options_ptr,
#     973                          run_metadata_ptr)
#     974       if run_metadata:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1213     # or if the call is a partial run that specifies feeds.
#    1214     if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1215       results = self._do_run(handle, final_targets, final_fetches,
#    1216                              feed_dict_tensor, options, run_metadata)
#    1217     else:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1376     feeds = dict((t.deref()._as_tf_output(), v) for t, v in feed_dict.items())
#    1377     fetches = [t._as_tf_output() for t in fetch_list]
# -> 1378     targets = [op._c_op for op in target_list]
#    1379
#    1380     # pylint: enable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/client/session.py in <listcomp>(.0)
#    1376     feeds = dict((t.deref()._as_tf_output(), v) for t, v in feed_dict.items())
#    1377     fetches = [t._as_tf_output() for t in fetch_list]
# -> 1378     targets = [op._c_op for op in target_list]
#    1379
#    1380     # pylint: enable=protected-access
#
# KeyboardInterrupt:
